# %% [markdown]
# #### Dojo Classification
# - l'Objectif de ce dojo est des prédire la variable income.
# (soure https://archive.ics.uci.edu/ml/datasets/adult)

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

columns = ["age", "work-class", "fnlwgt", "education", "education-num","marital-status", "occupation", "relationship",
          "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"]

# %%
import pandas as pd

# %%
df_adults = pd.read_csv(url, names=columns, sep=',', na_values='?', skipinitialspace = True)
df_adults.head()
# Out:
#    age        work-class  fnlwgt  ... hours-per-week  native-country income
# 0   39         State-gov   77516  ...             40   United-States  <=50K
# 1   50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2   38           Private  215646  ...             40   United-States  <=50K
# 3   53           Private  234721  ...             40   United-States  <=50K
# 4   28           Private  338409  ...             40            Cuba  <=50K
#
# [5 rows x 15 columns]

# %%
df_adults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   work-class      30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df_adults.isna().sum()
# Out:
# age                  0
# work-class        1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
df_adults['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %% [markdown]
# ## Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
X= df_adults[["age", "fnlwgt", "education-num",
          "capital-gain", "capital-loss", "hours-per-week"]]
y= df_adults['income']
X_train,X_test,y_train,y_test= train_test_split(X,y, random_state=42, train_size=0.8)

# %%
# validation_err = []
# for k in range(1,20):
#   KNN_class= KNeighborsClassifier(n_neighbors=k)
#   KNN_class.fit(X_train,y_train)
#   score=KNN_class.score(X_train, y_train)
#   score_predict=KNN_class.score(X_test, y_test)
#   validation_err.append(1-score_predict)
#   print("Pour k: {}, train score {}, différence score: {} ".format(k,score, score-score_predict))

# %%
KNN_class.score(X_test, y_test)
# Out:
# 0.8016275142023646

# %%
KNN_class.predict(X_test)
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '>50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
KNN_class= KNeighborsClassifier(n_neighbors=18)
KNN_class.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=18, p=2,
#                      weights='uniform')

# %%
df_adults['predict']=KNN_class.predict(X)

# %%
KNN_class.score(X,y)
# Out:
# 0.8028930315408004

# %%
# import matplotlib.pyplot as plt

# plt.plot(range(1, 20), validation_err)

# %%
df_adults
# Out:
#        age        work-class  fnlwgt  ... native-country  income predict
# 0       39         State-gov   77516  ...  United-States   <=50K   <=50K
# 1       50  Self-emp-not-inc   83311  ...  United-States   <=50K   <=50K
# 2       38           Private  215646  ...  United-States   <=50K   <=50K
# 3       53           Private  234721  ...  United-States   <=50K   <=50K
# 4       28           Private  338409  ...           Cuba   <=50K   <=50K
# ...    ...               ...     ...  ...            ...     ...     ...
# 32556   27           Private  257302  ...  United-States   <=50K   <=50K
# 32557   40           Private  154374  ...  United-States    >50K   <=50K
# 32558   58           Private  151910  ...  United-States   <=50K   <=50K
# 32559   22           Private  201490  ...  United-States   <=50K   <=50K
# 32560   52      Self-emp-inc  287927  ...  United-States    >50K    >50K
#
# [32561 rows x 16 columns]

# %%
df_sex =pd.get_dummies(df_adults['sex'])

# %%
#df_adults = pd.merge(df_adults, df_sex, how='inner')
df_adults_dummies = pd.get_dummies(df_adults, prefix=['sex', 'race'], columns=['sex', 'race'], drop_first=True)

# %%
df_adults_dummies.head()
# Out:
#    age        work-class  fnlwgt  ... race_Black  race_Other race_White
# 0   39         State-gov   77516  ...          0           0          1
# 1   50  Self-emp-not-inc   83311  ...          0           0          1
# 2   38           Private  215646  ...          0           0          1
# 3   53           Private  234721  ...          1           0          0
# 4   28           Private  338409  ...          1           0          0
#
# [5 rows x 19 columns]

# %%
X= df_adults_dummies[["age", "fnlwgt", "education-num",
          "capital-gain", "capital-loss", "hours-per-week", 'sex_Male', 'race_Asian-Pac-Islander',	'race_Black',	'race_Other',	'race_White']]
y= df_adults_dummies['income']
X_train,X_test,y_train,y_test= train_test_split(X,y, random_state=42, train_size=0.8)
