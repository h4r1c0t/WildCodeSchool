# %%
# Affiche le message "Je suis un wilder Data Analyst
print("Je suis un wilder Data Analyst")
# Out:
# Je suis un wilder Data Analyst

# %%
# Concatène la chaine de caractère précédente avec la suivante directement dans le print : "et peut-être que dans quelques années je serai Data scientist. "
print("Je suis un wilder Data Analyst","et peut-être que dans quelques années je serai Data scientist.")
# Out:
# Je suis un wilder Data Analyst et peut-être que dans quelques années je serai Data scientist.

# %%
# Utilise la méthode format pour afficher le message : "J'aime Python même si il ne m'aime pas toujours" . Tu passeras en paramètre de format le mot "Python" et "toujours"
p = 'python'
t = 'toujours'

print("J'aime {} même si il ne m'aime pas {}".format(p, t))
# Out:
# J'aime python même si il ne m'aime pas toujours

# %%
# Créer un programme qui vérifie la présence de la lettre i dans une chaine de caractère
string = 'skndfùsdfùksjiisfs'

for i in string:
  print(i)
  if i in string:
    print(i, string, "YES")

# %%
# Correction

string = 'skndfùsdfùksjiisfs'

if "a" in string:
  print("OK")

# %%
# Trouve le moyen de transformer la chaine de caractère précédente en liste
chaine = 'skndfùsdfùksjiisfs'
liste = list(chaine)
print(liste)
# Out:
# ['s', 'k', 'n', 'd', 'f', 'ù', 's', 'd', 'f', 'ù', 'k', 's', 'j', 'i', 'i', 's', 'f', 's']

# %%
# Affiche l'avant avant avant dernier élément de cette liste
chaine = 'skndfùsdfùksjiisfs'
liste = list(chaine)
print(chaine[-3])
# Out:
# s

# %%
# Parcours ta liste avec la boucle while
chaine = 'abcdefghijkl'
liste = list(chaine)
i= 0
while i + 1 <= len(liste):
  print(liste[i])
  i+=1
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j
# k
# l

# %%
# Parcours ta liste en n'affichant que les consonnes. Dans ta condition tu feras la comparaison avec les voyelles.

for i in liste:
  voyelles = ['a', 'e', 'i', 'o', 'u', 'y']
  if i not in voyelles:
    print(i, end = "")
# Out:
# bcdfghjkl

# %%
# Créer une fonction qui demande un nombre et l'affiche
def num():
  num = int(input())
  print(num)

num()
# Out:
# 666
# 666

# %%
# Modifie la fonction pour qu'elle convertisse l'input en int (on partira du principe que l'input n'est toujours composé que de nombre entier uniquement)
def num():
  num = input()
  if type(num) not int:
    num=int(i)

num()
# Out:
#   File "<ipython-input-1-0c086d5b0bdf>", line 3
#     if type(num) not int:
#                        ^
# SyntaxError: invalid syntax

# %%
# Modifie la fonction pour qu'elle teste si l'input est un nombre entier ou pas. Si c'est le cas elle le convertie en int
num = '2'
print(type(num))
# Out:
# <class 'str'>

# %%
num = str(input())
# Out:
# 2.0

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f9fbe1ee5c1d> in <module>()
# ----> 1 round(num)
#
# TypeError: type str doesn't define __round__ method

# %%
print(type(int(num)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d34b18c47afd> in <module>()
# ----> 1 print(type(int(num)))
#
# ValueError: invalid literal for int() with base 10: '2.0'

# %%
print(type(int(num)))
# Out:
# <class 'int'>

# %%
# Modifie la fonction pour qu'il ait plusieurs input : l'année de naissance, l'année actuelle et le prénom. 

# La fonction renvera : Bonjour "Prénom", nous sommes en "Année actuelle", tu as donc ou auras age
