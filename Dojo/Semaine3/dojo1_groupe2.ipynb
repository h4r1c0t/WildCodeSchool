# %%
# Affiche le message "Je suis un wilder Data Analyst"
print("Je suis un wilder Data Analyst")
# Out:
# Je suis un wilder Data Analyst

# %%
# Concatène la chaine de caractère précédente avec la suivante directement dans le print : "et peut-être que dans quelques années je serai Data scientist. "
print ("Je suis un wilder Data Analyst et peut-être que dans quelques années je serai Data scientist. " )
# Out:
# Je suis un wilder Data Analyst et peut-être que dans quelques années je serai Data scientist.

# %%
# Utilise la méthode format pour afficher le message : "J'aime Python même si il ne m'aime pas toujours" . Tu passeras en paramètre de format le mot "Python" et "toujours"
print("J'aime {} même si il ne m'aime pas {}".format ("Python", "toujours"))
# Out:
# J'aime Python même si il ne m'aime pas toujours

# %%
# Créer un programme qui vérifie la présence de la lettre i dans une chaine de caractère
def fonction_lettrei (chaine):
    for letter in chaine:
        if letter =="i" :
            print("la lettre i est présente")
fonction_lettrei ("iabc")
# Out:
# la lettre i est présente

# %%
# Trouve le moyen de transformer la chaine de caractère précédente en liste
chaine="Je suis un wilder Data Analyst"
chaine.split()
# Out:
# ['Je', 'suis', 'un', 'wilder', 'Data', 'Analyst']

# %%
# Affiche l'avant avant avant dernier élément de cette liste
print(chaine[-3])
# Out:
# y

# %%
# Parcours ta liste avec la boucle while
x = 0
chaine="Je suis un wilder Data Analyst"

while x <= len(chaine) - 1:
  for i in chaine:
    print(i)
    x += 1

# %%
# Parcours ta liste avec la boucle while
x = 0
chaine="Je suis un wilder Data Analyst"
myList = list(chaine)

while x <= len(myList) - 1:
  print(x, myList[x])
  x += 1

# %%
chaine="Je suis un wilder Data Analyst"
myList = list(chaine)
print(myList)
# Out:
# ['J', 'e', ' ', 's', 'u', 'i', 's', ' ', 'u', 'n', ' ', 'w', 'i', 'l', 'd', 'e', 'r', ' ', 'D', 'a', 't', 'a', ' ', 'A', 'n', 'a', 'l', 'y', 's', 't']

# %%
# Parcours ta liste en n'affichant que les consonnes. Dans ta condition tu feras la comparaison avec les voyelles.

voyelles = ["a", "e", "i", "o", "u", "y"]
chaine=["b", "e", "i", "o", "u", "y", "s"]

for i in chaine:
  if i not in voyelles:
    print(i)
# Out:
# b
# s

# %%
voyelles = ["a", "e", "i", "o", "u", "y"]
chaine="Je suis un wilder Data Analyst"

# %%
print(type(voyelles), type(chaine))
# Out:
# <class 'list'> <class 'str'>

# %%
maListe=chaine.split()
print(maListe)
# Out:
# ['Je', 'suis', 'un', 'wilder', 'Data', 'Analyst']

# %%
# Out:
# ['J', 'e']
# ['s', 'u', 'i', 's']
# ['u', 'n']
# ['w', 'i', 'l', 'd', 'e', 'r']
# ['D', 'a', 't', 'a']
# ['A', 'n', 'a', 'l', 'y', 's', 't']
# []

# %%
for mot in maListe:
   print(mot)
   for lettre in mot:
     if lettre not in voyelles:
      print(lettre, "not in voyelles")

# %%
for mot in range(len(myList)):
  print(mot)

# %%
for i in range(len(maListe)):
  if maListe[i] not in voyelles:
    print(maListe[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7761fff60de> in <module>()
# ----> 1 for i in range(len(maListe)):
#       2   if maListe[i] not in voyelles:
#       3     print(maListe[i])
#
# NameError: name 'maListe' is not defined

# %%
# Créer une fonction qui demande un nombre et l'affiche
def test():
  print("quel est le nombre")
  chiffre=int(input())
  print(chiffre)

test()
# Out:
# quel est le nombre
# 3
# 3

# %%
# Modifie la fonction pour qu'elle verifie si l'input en int (on partira du principe que l'input n'est toujours composé que de nombre entier uniquement)
def test():
  print("quel est le nombre")
  chiffre=input()
  if type(chiffre)==int:
    print(chiffre)

test()
# Out:
# quel est le nombre
# 3

# %%
# Modifie la fonction pour qu'il ait plusieurs input : l'année de naissance, l'année actuel et le prénom. 
# La fonction renvera : Bonjour "Prénom", nous sommes en "Année actuelle", tu as donc ou auras age
def test(naissance, annee, prenom):
  naissance=int(input("saisi l'année de ta naissance"))
  annee=int(input("saisi l'année actuelle"))
  prenom=input("quel est ton prénom ?")

  print("Bonjour ",prenom, " nous sommes en ", annee, " tu as donc ", annee-naissance)

test(1992, 2020, "Alex")
# Out:
# saisi l'année de ta naissance1992
# saisi l'année actuelle2020
# quel est ton prénom ?alex
# Bonjour  alex  nous sommes en  2020  tu as donc  28
