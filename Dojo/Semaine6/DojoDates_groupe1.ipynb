# %% [markdown]
# ![alt text](https://)- Importez le jeu de données.
# - Assurez vous qu'il n'y a pas de valeurs manquantes.
# - Affichez le type de chaque variable.
# - Quelle est la température maximale (ville au choix).
# - Donnez la température maximale **moyenne** pour chaque mois (ville au choix).
# - Donnez la température maximale **maximale** pour chaque mois (ville au choix).
# - Dans une même table, mettre les données  MAX_TEMPERATURE_C, MIN_TEMPERATURE_C PRECIP_TOTAL_DAY_MM  et CLOUDCOVER_AVG_PERCENT pour Toulouse et pour Lille (1 seul DataFrame pour les 2 villes).
# - Afficher la pluviométrie totale par ville et par mois.

# %%
# Importez le jeu de données.
import pandas as pd
pth_lill= "https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv"
pth_tlse= "https://raw.githubusercontent.com/cesreve/wild/master/export-toulouse2019.csv"
data1 = pd.read_csv(pth_lill,sep=',',skiprows = [0,1,2])
data2 = pd.read_csv(pth_tlse,sep=',',skiprows = [0,1,2])
data2
# Out:
#            DATE  MAX_TEMPERATURE_C  ...  SUNHOUR                 OPINION
# 0    2019-01-01                  6  ...      8.7  météo très défavorable
# 1    2019-01-02                  7  ...      6.9  météo très défavorable
# 2    2019-01-03                  8  ...      8.7  météo très défavorable
# 3    2019-01-04                  7  ...      8.7  météo très défavorable
# 4    2019-01-05                  6  ...      8.7  météo très défavorable
# ..          ...                ...  ...      ...                     ...
# 360  2019-12-27                 12  ...      8.7       météo défavorable
# 361  2019-12-28                 13  ...      8.7          météo correcte
# 362  2019-12-29                 11  ...      8.7  météo très défavorable
# 363  2019-12-30                 10  ...      8.7  météo très défavorable
# 364  2019-12-31                 11  ...      8.7  météo très défavorable
#
# [365 rows x 22 columns]

# %%
# Assurez vous qu'il n'y a pas de valeurs manquantes.
data1.isna().sum()
# Out:
# DATE                      0
# MAX_TEMPERATURE_C         0
# MIN_TEMPERATURE_C         0
# WINDSPEED_MAX_KMH         0
# TEMPERATURE_MORNING_C     0
# TEMPERATURE_NOON_C        0
# TEMPERATURE_EVENING_C     0
# PRECIP_TOTAL_DAY_MM       0
# HUMIDITY_MAX_PERCENT      0
# VISIBILITY_AVG_KM         0
# PRESSURE_MAX_MB           0
# CLOUDCOVER_AVG_PERCENT    0
# HEATINDEX_MAX_C           0
# DEWPOINT_MAX_C            0
# WINDTEMP_MAX_C            0
# WEATHER_CODE_MORNING      0
# WEATHER_CODE_NOON         0
# WEATHER_CODE_EVENING      0
# TOTAL_SNOW_MM             0
# UV_INDEX                  0
# SUNHOUR                   0
# OPINION                   0
# dtype: int64

# %%
data2.isna().sum()
# Out:
# DATE                      0
# MAX_TEMPERATURE_C         0
# MIN_TEMPERATURE_C         0
# WINDSPEED_MAX_KMH         0
# TEMPERATURE_MORNING_C     0
# TEMPERATURE_NOON_C        0
# TEMPERATURE_EVENING_C     0
# PRECIP_TOTAL_DAY_MM       0
# HUMIDITY_MAX_PERCENT      0
# VISIBILITY_AVG_KM         0
# PRESSURE_MAX_MB           0
# CLOUDCOVER_AVG_PERCENT    0
# HEATINDEX_MAX_C           0
# DEWPOINT_MAX_C            0
# WINDTEMP_MAX_C            0
# WEATHER_CODE_MORNING      0
# WEATHER_CODE_NOON         0
# WEATHER_CODE_EVENING      0
# TOTAL_SNOW_MM             0
# UV_INDEX                  0
# SUNHOUR                   0
# OPINION                   0
# dtype: int64

# %%
# Affichez le type de chaque variable.

data1.dtypes

# %%
data2.dtypes
# Out:
# DATE                       object
# MAX_TEMPERATURE_C           int64
# MIN_TEMPERATURE_C           int64
# WINDSPEED_MAX_KMH           int64
# TEMPERATURE_MORNING_C       int64
# TEMPERATURE_NOON_C          int64
# TEMPERATURE_EVENING_C       int64
# PRECIP_TOTAL_DAY_MM       float64
# HUMIDITY_MAX_PERCENT        int64
# VISIBILITY_AVG_KM         float64
# PRESSURE_MAX_MB             int64
# CLOUDCOVER_AVG_PERCENT    float64
# HEATINDEX_MAX_C             int64
# DEWPOINT_MAX_C              int64
# WINDTEMP_MAX_C              int64
# WEATHER_CODE_MORNING        int64
# WEATHER_CODE_NOON           int64
# WEATHER_CODE_EVENING        int64
# TOTAL_SNOW_MM             float64
# UV_INDEX                    int64
# SUNHOUR                   float64
# OPINION                    object
# dtype: object

# %%
# Quelle est la température maximale (ville au choix).

data1['MAX_TEMPERATURE_C'].max()
# Out:
# 38

# %%
# Donnez la température maximale moyenne pour chaque mois (ville au choix).
import datetime
#data_max = data1['MAX_TEMPERATURE_C'].to_datetime(data1.MAX_TEMPERATURE_C)
#pd.to_datetime(['1/1/2018', np.datetime64('2018-01-01'),  datetime.datetime(2018, 1, 1)])
data1_copy = data1.copy()
data1_copy = data1_copy.loc[:, ['DATE', 'MAX_TEMPERATURE_C']]
#data_max = pd.to_datetime(data1['DATE'])
#data_max.dt.month

# %%
data1_copy['DATE'] = pd.to_datetime(data1['DATE'])
data1_copy['DATE'].dt.month
data1_copy.groupby(['DATE']).mean()
# Out:
#             MAX_TEMPERATURE_C
# DATE
# 2019-01-01                  9
# 2019-01-02                  7
# 2019-01-03                  6
# 2019-01-04                  5
# 2019-01-05                  6
# ...                       ...
# 2019-12-27                  9
# 2019-12-28                  6
# 2019-12-29                  5
# 2019-12-30                  6
# 2019-12-31                  6
#
# [365 rows x 1 columns]

# %%
Donnez la température maximale maximale pour chaque mois (ville au choix).
Dans une même table, mettre les données MAX_TEMPERATURE_C, MIN_TEMPERATURE_C PRECIP_TOTAL_DAY_MM et CLOUDCOVER_AVG_PERCENT pour Toulouse et pour Lille (1 seul DataFrame pour les 2 villes).
Afficher la pluviométrie totale par ville et par mois.
