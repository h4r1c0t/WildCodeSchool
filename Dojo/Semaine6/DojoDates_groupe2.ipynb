# %% [markdown]
# - Importez le jeu de données.
# - Assurez vous qu'il n'y a pas de valeurs manquantes.
# - Affichez le type de chaque variable.
# - Quelle est la température maximale (ville au choix).
# - Donnez la température maximale moyenne pour chaque mois (ville au choix).
# - Donnez la température maximale maximale pour chaque mois (ville au choix).
# - Dans une même table, mettre les données  MAX_TEMPERATURE_C, MIN_TEMPERATURE_C PRECIP_TOTAL_DAY_MM  et CLOUDCOVER_AVG_PERCENT pour Toulouse et pour Lille (1 seul DataFrame pour les 2 villes).
# - Afficher la pluviométrie totale par ville et par mois.

# %%
pth_lill= "https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv"
pth_tlse= "https://raw.githubusercontent.com/cesreve/wild/master/export-toulouse2019.csv"

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv" , error_bad_lines=False, sep=',', skiprows=3 )
df
# Out:
#            DATE  MAX_TEMPERATURE_C  ...  SUNHOUR                 OPINION
# 0    2019-01-01                  9  ...      3.0       météo défavorable
# 1    2019-01-02                  7  ...      3.0  météo très défavorable
# 2    2019-01-03                  6  ...      3.0  météo très défavorable
# 3    2019-01-04                  5  ...      3.0  météo très défavorable
# 4    2019-01-05                  6  ...      3.0  météo très défavorable
# ..          ...                ...  ...      ...                     ...
# 360  2019-12-27                  9  ...      8.0       météo défavorable
# 361  2019-12-28                  6  ...      8.0  météo très défavorable
# 362  2019-12-29                  5  ...      8.0  météo très défavorable
# 363  2019-12-30                  6  ...      8.0  météo très défavorable
# 364  2019-12-31                  6  ...      8.0  météo très défavorable
#
# [365 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# DATE                      0
# MAX_TEMPERATURE_C         0
# MIN_TEMPERATURE_C         0
# WINDSPEED_MAX_KMH         0
# TEMPERATURE_MORNING_C     0
# TEMPERATURE_NOON_C        0
# TEMPERATURE_EVENING_C     0
# PRECIP_TOTAL_DAY_MM       0
# HUMIDITY_MAX_PERCENT      0
# VISIBILITY_AVG_KM         0
# PRESSURE_MAX_MB           0
# CLOUDCOVER_AVG_PERCENT    0
# HEATINDEX_MAX_C           0
# DEWPOINT_MAX_C            0
# WINDTEMP_MAX_C            0
# WEATHER_CODE_MORNING      0
# WEATHER_CODE_NOON         0
# WEATHER_CODE_EVENING      0
# TOTAL_SNOW_MM             0
# UV_INDEX                  0
# SUNHOUR                   0
# OPINION                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE                    365 non-null    object
#  1   MAX_TEMPERATURE_C       365 non-null    int64
#  2   MIN_TEMPERATURE_C       365 non-null    int64
#  3   WINDSPEED_MAX_KMH       365 non-null    int64
#  4   TEMPERATURE_MORNING_C   365 non-null    int64
#  5   TEMPERATURE_NOON_C      365 non-null    int64
#  6   TEMPERATURE_EVENING_C   365 non-null    int64
#  7   PRECIP_TOTAL_DAY_MM     365 non-null    float64
#  8   HUMIDITY_MAX_PERCENT    365 non-null    int64
#  9   VISIBILITY_AVG_KM       365 non-null    float64
#  10  PRESSURE_MAX_MB         365 non-null    int64
#  11  CLOUDCOVER_AVG_PERCENT  365 non-null    float64
#  12  HEATINDEX_MAX_C         365 non-null    int64
#  13  DEWPOINT_MAX_C          365 non-null    int64
#  14  WINDTEMP_MAX_C          365 non-null    int64
#  15  WEATHER_CODE_MORNING    365 non-null    int64
#  16  WEATHER_CODE_NOON       365 non-null    int64
#  17  WEATHER_CODE_EVENING    365 non-null    int64
#  18  TOTAL_SNOW_MM           365 non-null    float64
#  19  UV_INDEX                365 non-null    int64
#  20  SUNHOUR                 365 non-null    float64
#  21  OPINION                 365 non-null    object
# dtypes: float64(5), int64(15), object(2)
# memory usage: 62.9+ KB

# %%
df.max()
# Out:
# DATE                                  2019-12-31
# MAX_TEMPERATURE_C                             38
# MIN_TEMPERATURE_C                             23
# WINDSPEED_MAX_KMH                             51
# TEMPERATURE_MORNING_C                         25
# TEMPERATURE_NOON_C                            35
# TEMPERATURE_EVENING_C                         36
# PRECIP_TOTAL_DAY_MM                         29.2
# HUMIDITY_MAX_PERCENT                         100
# VISIBILITY_AVG_KM                             20
# PRESSURE_MAX_MB                             1041
# CLOUDCOVER_AVG_PERCENT                       100
# HEATINDEX_MAX_C                               40
# DEWPOINT_MAX_C                                22
# WINDTEMP_MAX_C                                29
# WEATHER_CODE_MORNING                         389
# WEATHER_CODE_NOON                            389
# WEATHER_CODE_EVENING                         362
# TOTAL_SNOW_MM                                8.9
# UV_INDEX                                       1
# SUNHOUR                                     16.7
# OPINION                   météo très défavorable
# dtype: object

# %%
#df[df["MAX_TEMPERATURE_C"].mean()].groupby("DATE")
# df["DATE"] = pd.to_datetime(df["DATE"])
# df.set_index("DATE", inplace=True)
df.groupby(pd.Grouper(freq="M")).mean()
#df.info()
# pd.DatetimeIndex(df.DATE).to_period("M")
# df.groupby["DATE"]
# Out:
#             MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  ...  UV_INDEX    SUNHOUR
# DATE                                              ...
# 2019-01-31           5.612903           3.354839  ...       1.0   4.167742
# 2019-02-28          10.857143           5.464286  ...       1.0   7.796429
# 2019-03-31          12.000000           6.322581  ...       1.0   7.509677
# 2019-04-30          15.433333           7.466667  ...       1.0  11.030000
# 2019-05-31          16.258065           8.774194  ...       1.0  11.764516
# 2019-06-30          22.433333          13.766667  ...       1.0  14.403333
# 2019-07-31          23.903226          15.258065  ...       1.0  13.274194
# 2019-08-31          24.387097          16.032258  ...       1.0  12.561290
# 2019-09-30          19.300000          12.666667  ...       1.0   8.490000
# 2019-10-31          15.387097          10.129032  ...       1.0   6.535484
# 2019-11-30           9.333333           4.866667  ...       1.0   5.470000
# 2019-12-31           8.064516           4.225806  ...       1.0   5.367742
#
# [12 rows x 20 columns]

# %%
df
# Out:
#             MAX_TEMPERATURE_C  ...                 OPINION
# DATE                           ...
# 2019-01-01                  9  ...       météo défavorable
# 2019-01-02                  7  ...  météo très défavorable
# 2019-01-03                  6  ...  météo très défavorable
# 2019-01-04                  5  ...  météo très défavorable
# 2019-01-05                  6  ...  météo très défavorable
# ...                       ...  ...                     ...
# 2019-12-27                  9  ...       météo défavorable
# 2019-12-28                  6  ...  météo très défavorable
# 2019-12-29                  5  ...  météo très défavorable
# 2019-12-30                  6  ...  météo très défavorable
# 2019-12-31                  6  ...  météo très défavorable
#
# [365 rows x 21 columns]
