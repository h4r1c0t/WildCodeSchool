# %% [markdown]
# - Importez le jeu de données (ville au choix).
# - Assurez vous qu'il n'y a pas de valeurs manquantes.
# - Affichez le type de chaque variable.
# - Quelle est la température maximale sue l'année (ville au choix).
# - Donnez la température maximale moyenne pour chaque mois (ville au choix).
# - Donnez la température maximale maximale pour chaque mois (ville au choix).
# - Dans une même table, mettre les données  MAX_TEMPERATURE_C, MIN_TEMPERATURE_C PRECIP_TOTAL_DAY_MM  et CLOUDCOVER_AVG_PERCENT pour Toulouse et pour Lille (1 seul DataFrame pour les 2 villes).
# - Afficher la pluviométrie totale par ville et par mois.

# %%
pth_lill= "https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv"
pth_tlse= "https://raw.githubusercontent.com/cesreve/wild/master/export-toulouse2019.csv"

# %%
import pandas as pd
import numpy as np

#df=pd.read_csv('https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv', header=2, sep=',')
# error_bad_lines=False
#df

df=pd.read_csv('https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv', skiprows = 3, sep=',')
df
# Out:
#            DATE  MAX_TEMPERATURE_C  ...  SUNHOUR                 OPINION
# 0    2019-01-01                  9  ...      3.0       météo défavorable
# 1    2019-01-02                  7  ...      3.0  météo très défavorable
# 2    2019-01-03                  6  ...      3.0  météo très défavorable
# 3    2019-01-04                  5  ...      3.0  météo très défavorable
# 4    2019-01-05                  6  ...      3.0  météo très défavorable
# ..          ...                ...  ...      ...                     ...
# 360  2019-12-27                  9  ...      8.0       météo défavorable
# 361  2019-12-28                  6  ...      8.0  météo très défavorable
# 362  2019-12-29                  5  ...      8.0  météo très défavorable
# 363  2019-12-30                  6  ...      8.0  météo très défavorable
# 364  2019-12-31                  6  ...      8.0  météo très défavorable
#
# [365 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# DATE                      0
# MAX_TEMPERATURE_C         0
# MIN_TEMPERATURE_C         0
# WINDSPEED_MAX_KMH         0
# TEMPERATURE_MORNING_C     0
# TEMPERATURE_NOON_C        0
# TEMPERATURE_EVENING_C     0
# PRECIP_TOTAL_DAY_MM       0
# HUMIDITY_MAX_PERCENT      0
# VISIBILITY_AVG_KM         0
# PRESSURE_MAX_MB           0
# CLOUDCOVER_AVG_PERCENT    0
# HEATINDEX_MAX_C           0
# DEWPOINT_MAX_C            0
# WINDTEMP_MAX_C            0
# WEATHER_CODE_MORNING      0
# WEATHER_CODE_NOON         0
# WEATHER_CODE_EVENING      0
# TOTAL_SNOW_MM             0
# UV_INDEX                  0
# SUNHOUR                   0
# OPINION                   0
# dtype: int64

# %%
dft=df.dtypes
dft
# Out:
# DATE                       object
# MAX_TEMPERATURE_C           int64
# MIN_TEMPERATURE_C           int64
# WINDSPEED_MAX_KMH           int64
# TEMPERATURE_MORNING_C       int64
# TEMPERATURE_NOON_C          int64
# TEMPERATURE_EVENING_C       int64
# PRECIP_TOTAL_DAY_MM       float64
# HUMIDITY_MAX_PERCENT        int64
# VISIBILITY_AVG_KM         float64
# PRESSURE_MAX_MB             int64
# CLOUDCOVER_AVG_PERCENT    float64
# HEATINDEX_MAX_C             int64
# DEWPOINT_MAX_C              int64
# WINDTEMP_MAX_C              int64
# WEATHER_CODE_MORNING        int64
# WEATHER_CODE_NOON           int64
# WEATHER_CODE_EVENING        int64
# TOTAL_SNOW_MM             float64
# UV_INDEX                    int64
# SUNHOUR                   float64
# OPINION                    object
# dtype: object

# %%
#df[df.max('MAX_TEMPERATURE_C')]

df['MAX_TEMPERATURE_C'].max()
# Out:
# 38

# %%
print(df.groupby("MAX_TEMPERATURE_C").max())
# Out:
#                          DATE  ...                 OPINION
# MAX_TEMPERATURE_C              ...
# 0                  2019-01-31  ...  météo très défavorable
# 1                  2019-01-24  ...  météo très défavorable
# 2                  2019-01-30  ...  météo très défavorable
# 3                  2019-02-04  ...  météo très défavorable
# 4                  2019-12-01  ...  météo très défavorable
# 5                  2019-12-29  ...  météo très défavorable
# 6                  2019-12-31  ...  météo très défavorable
# 7                  2019-12-02  ...  météo très défavorable
# 8                  2019-12-25  ...  météo très défavorable
# 9                  2019-12-27  ...  météo très défavorable
# 10                 2019-12-07  ...  météo très défavorable
# 11                 2019-12-24  ...  météo très défavorable
# 12                 2019-12-20  ...  météo très défavorable
# 13                 2019-12-17  ...       météo défavorable
# 14                 2019-11-02  ...  météo très défavorable
# 15                 2019-10-18  ...       météo défavorable
# 16                 2019-10-25  ...       météo défavorable
# 17                 2019-10-08  ...       météo défavorable
# 18                 2019-10-24  ...         météo favorable
# 19                 2019-10-26  ...         météo favorable
# 20                 2019-09-23  ...         météo favorable
# 21                 2019-10-14  ...  météo très défavorable
# 22                 2019-10-13  ...         météo favorable
# 23                 2019-08-29  ...  météo très défavorable
# 24                 2019-09-22  ...         météo favorable
# 25                 2019-09-14  ...         météo favorable
# 26                 2019-09-15  ...         météo favorable
# 27                 2019-08-31  ...         météo favorable
# 28                 2019-07-26  ...         météo favorable
# 29                 2019-06-25  ...         météo favorable
# 30                 2019-08-24  ...         météo favorable
# 32                 2019-08-26  ...         météo favorable
# 33                 2019-08-27  ...         météo favorable
# 38                 2019-07-25  ...          météo correcte
#
# [34 rows x 21 columns]
