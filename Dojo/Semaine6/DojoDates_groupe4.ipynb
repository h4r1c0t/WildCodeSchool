# %% [markdown]
# - Importez le jeu de données.
# - Assurez vous qu'il n'y a pas de valeurs manquantes.
# - Affichez le type de chaque variable.
# - Quelle est la température maximale (ville au choix).
# - Donnez la température maximale moyenne pour chaque mois (ville au choix).
# - Donnez la température maximale maximale pour chaque mois (ville au choix).
# - Dans une même table, mettre les données  MAX_TEMPERATURE_C, MIN_TEMPERATURE_C PRECIP_TOTAL_DAY_MM  et CLOUDCOVER_AVG_PERCENT pour Toulouse et pour Lille (1 seul DataFrame pour les 2 villes).
# - Afficher la pluviométrie totale par ville et par mois.

# %%
pth_lill= "https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv"
pth_tlse= "https://raw.githubusercontent.com/cesreve/wild/master/export-toulouse2019.csv"

# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("https://raw.githubusercontent.com/cesreve/wild/master/export-lille2019.csv", sep=',', header=0, skiprows=[0,1,2])
df
# Out:
#            DATE  MAX_TEMPERATURE_C  ...  SUNHOUR                 OPINION
# 0    2019-01-01                  9  ...      3.0       météo défavorable
# 1    2019-01-02                  7  ...      3.0  météo très défavorable
# 2    2019-01-03                  6  ...      3.0  météo très défavorable
# 3    2019-01-04                  5  ...      3.0  météo très défavorable
# 4    2019-01-05                  6  ...      3.0  météo très défavorable
# ..          ...                ...  ...      ...                     ...
# 360  2019-12-27                  9  ...      8.0       météo défavorable
# 361  2019-12-28                  6  ...      8.0  météo très défavorable
# 362  2019-12-29                  5  ...      8.0  météo très défavorable
# 363  2019-12-30                  6  ...      8.0  météo très défavorable
# 364  2019-12-31                  6  ...      8.0  météo très défavorable
#
# [365 rows x 22 columns]

# %%
df.notna().sum()
# Out:
# DATE                      365
# MAX_TEMPERATURE_C         365
# MIN_TEMPERATURE_C         365
# WINDSPEED_MAX_KMH         365
# TEMPERATURE_MORNING_C     365
# TEMPERATURE_NOON_C        365
# TEMPERATURE_EVENING_C     365
# PRECIP_TOTAL_DAY_MM       365
# HUMIDITY_MAX_PERCENT      365
# VISIBILITY_AVG_KM         365
# PRESSURE_MAX_MB           365
# CLOUDCOVER_AVG_PERCENT    365
# HEATINDEX_MAX_C           365
# DEWPOINT_MAX_C            365
# WINDTEMP_MAX_C            365
# WEATHER_CODE_MORNING      365
# WEATHER_CODE_NOON         365
# WEATHER_CODE_EVENING      365
# TOTAL_SNOW_MM             365
# UV_INDEX                  365
# SUNHOUR                   365
# OPINION                   365
# dtype: int64

# %%
df.dtypes
# Out:
# DATE                       object
# MAX_TEMPERATURE_C           int64
# MIN_TEMPERATURE_C           int64
# WINDSPEED_MAX_KMH           int64
# TEMPERATURE_MORNING_C       int64
# TEMPERATURE_NOON_C          int64
# TEMPERATURE_EVENING_C       int64
# PRECIP_TOTAL_DAY_MM       float64
# HUMIDITY_MAX_PERCENT        int64
# VISIBILITY_AVG_KM         float64
# PRESSURE_MAX_MB             int64
# CLOUDCOVER_AVG_PERCENT    float64
# HEATINDEX_MAX_C             int64
# DEWPOINT_MAX_C              int64
# WINDTEMP_MAX_C              int64
# WEATHER_CODE_MORNING        int64
# WEATHER_CODE_NOON           int64
# WEATHER_CODE_EVENING        int64
# TOTAL_SNOW_MM             float64
# UV_INDEX                    int64
# SUNHOUR                   float64
# OPINION                    object
# dtype: object

# %%
df["MAX_TEMPERATURE_C"].max()
# Out:
# 38

# %%
for x in df.itertuples():
  somme= somme + df['MAX_TEMPERATURE_C']
  

df["MAX_TEMPERATURE_C"].mean()
# Out:
# 15.26849315068493

# %%
df["DATE"] = pd.to_datetime(df["DATE"])
df = df[['MAX_TEMPERATURE_C'].groupby[('DATE')].mean()]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-45a253e83b7c> in <module>()
#       1 df["DATE"] = pd.to_datetime(df["DATE"])
# ----> 2 df = df[['MAX_TEMPERATURE_C'].groupby[('DATE')].mean()]
#       3 df
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
col= ['MAX_TEMPERATURE_C', 'MIN_TEMPERATURE_C','PRECIP_TOTAL_DAY_MM','CLOUDCOVER_AVG_PERCENT']
df_Lille=df_Lille[col]

# %%
df_Lille=pd.read_csv(pth_lill, sep=',', header=0, skiprows=[0,1,2], parse_dates=['DATE'])
df_Lille=df_Lille[col]
df_Lille['ville']="Lille"
df_Toulouse=pd.read_csv(pth_tlse, sep=',', header=0, skiprows=[0,1,2], parse_dates=['DATE'])
df_Toulouse=df_Toulouse[col]
df_Toulouse['ville']="Toulouse"
df_total=pd.concat([df_Lille, df_Toulouse])
print(df_total)
# Out:
#      MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  ...  CLOUDCOVER_AVG_PERCENT     ville
# 0                    9                  7  ...                  85.375     Lille
# 1                    7                  6  ...                  85.625     Lille
# 2                    6                  6  ...                  86.375     Lille
# 3                    5                  4  ...                  80.375     Lille
# 4                    6                  6  ...                  95.625     Lille
# ..                 ...                ...  ...                     ...       ...
# 360                 12                  6  ...                  30.125  Toulouse
# 361                 13                  6  ...                  28.875  Toulouse
# 362                 11                  5  ...                   3.750  Toulouse
# 363                 10                  4  ...                   5.875  Toulouse
# 364                 11                  5  ...                  20.375  Toulouse
#
# ...

# %%
pd.DataFrame(df_total.groupby(['ville',pd.Grouper(key='DATE', freq='M')])["MAX_TEMPERATURE_C"].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d380cf0f1eaa> in <module>()
# ----> 1 pd.DataFrame(df_total.groupby(['ville',pd.Grouper(key='DATE', freq='M')])["MAX_TEMPERATURE_C"].mean())
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...
